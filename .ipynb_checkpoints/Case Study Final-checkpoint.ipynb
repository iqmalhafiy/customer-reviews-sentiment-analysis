# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv ('Womens Clothing E-Commerce Reviews.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
df.shape
# Out:
# (23486, 11)

# %% [markdown]
# Means the dataframe has 23488 rows and 11 coloums

# %% [markdown]
# # Select 2Coloums

# %%
reviews_df = df[["Review Text","Rating"]]
reviews_df.head()
# Out:
#                                          Review Text  Rating
# 0  Absolutely wonderful - silky and sexy and comf...       4
# 1  Love this dress!  it's sooo pretty.  i happene...       5
# 2  I had such high hopes for this dress and reall...       3
# 3  I love, love, love this jumpsuit. it's fun, fl...       5
# 4  This shirt is very flattering to all due to th...       5

# %% [markdown]
# # Remove Nan value

# %%
reviews_df.isnull().any()
# Out:
# Review Text     True
# Rating         False
# dtype: bool

# %%
nan_rows = reviews_df[reviews_df['Review Text'].isnull()]
print(nan_rows)
# Out:
#       Review Text  Rating
# 92            NaN       5
# 93            NaN       5
# 98            NaN       5
# 135           NaN       4
# 142           NaN       5
# ...           ...     ...
# 23258         NaN       4
# 23301         NaN       5
# 23303         NaN       5
# 23470         NaN       5
# 23480         NaN       5
#
# [845 rows x 2 columns]

# %%
reviews_df = reviews_df.dropna()
reviews_df = reviews_df.reset_index(drop=True)
reviews_df.isnull().any()
# Out:
# Review Text    False
# Rating         False
# dtype: bool

# %%
reviews_df.tail()
# Out:
#                                              Review Text  Rating
# 22636  I was very happy to snag this dress at such a ...       5
# 22637  It reminds me of maternity clothes. soft, stre...       3
# 22638  This fit well, but the top was very see throug...       3
# 22639  I bought this dress for a wedding i have this ...       3
# 22640  This dress in a lovely platinum is feminine an...       5

# %% [markdown]
# ## Count Rows

# %%
reviews_df['Rating'].value_counts()
# Out:
# 5    12540
# 4     4908
# 3     2823
# 2     1549
# 1      821
# Name: Rating, dtype: int64

# %%
import matplotlib.pyplot as plt
reviews_df["Rating"].value_counts().plot(kind='bar')
plt.xlabel("Ratings")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# # Preprocessing Data

# %%
import nltk

# return the wordnet object value corresponding to the POS tag
from nltk.corpus import wordnet

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer

clothes =['dress','color','wear','top','sweater','material','shirt','jeans','pant',
          'skirt','order','white','black','fabric','blouse','sleeve','even', 'jacket']

def clean_text(text):
    
    # lower text
    text = text.lower()
    
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop and x not in clothes]
    
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    
    # pos tag text
    pos_tags = pos_tag(text)
    
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    
    # join all
    text = " ".join(text)
    return(text)

# clean text data
reviews_df["review_clean"] = reviews_df["Review Text"].apply(lambda x: clean_text(x))

# %%
reviews_df.head()
# Out:
#                                          Review Text  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...                1
# 1  Love this dress!  it's sooo pretty.  i happene...                1
# 2  I had such high hopes for this dress and reall...                0
# 3  I love, love, love this jumpsuit. it's fun, fl...                1
# 4  This shirt is very flattering to all due to th...                1
#
#                                         review_clean
# 0        absolutely wonderful silky sexy comfortable
# 1  love sooo pretty happen find store i'm glad bc...
# 2  high hope really want work initially order pet...
# 3  love love love jumpsuit fun flirty fabulous ev...
# 4  flatter due adjustable front tie perfect lengt...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color = 'white',
        max_words = 200,
        max_font_size = 40, 
        scale = 3,
        random_state = 42
    ).generate(str(data))

    fig = plt.figure(1, figsize = (20, 20))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize = 20)
        fig.subplots_adjust(top = 2.3)

    plt.imshow(wordcloud)
    plt.show()
    
# print wordcloud
show_wordcloud(reviews_df["review_clean"])

# %%
positive = reviews_df[reviews_df["Recommended IND"]== 1]
negative = reviews_df[reviews_df["Recommended IND"] == 0]
positive.head()
# Out:
#                                          Review Text  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...                1
# 1  Love this dress!  it's sooo pretty.  i happene...                1
# 3  I love, love, love this jumpsuit. it's fun, fl...                1
# 4  This shirt is very flattering to all due to th...                1
# 6  I aded this in my basket at hte last mintue to...                1
#
#                                         review_clean
# 0        absolutely wonderful silky sexy comfortable
# 1  love sooo pretty happen find store i'm glad bc...
# 3  love love love jumpsuit fun flirty fabulous ev...
# 4  flatter due adjustable front tie perfect lengt...
# 6  aded basket hte last mintue see would look lik...

# %%
negative.head()
# Out:
#                                           Review Text  Recommended IND  \
# 2   I had such high hopes for this dress and reall...                0
# 5   I love tracy reese dresses, but this one is no...                0
# 10  Dress runs small esp where the zipper area run...                0
# 22  First of all, this is not pullover styling. th...                0
# 25  Loved the material, but i didnt really look at...                0
#
#                                          review_clean
# 2   high hope really want work initially order pet...
# 5   love tracy reese dress one petite foot tall us...
# 10  run small esp zipper area run order sp typical...
# 22  first pullover style side zipper purchase knew...
# 25  love didnt really look long purchase large med...

# %%
reviews_df['review_clean'][1]
# Out:
# "love sooo pretty happen find store i'm glad bc never would order online bc petite buy petite love length hit little knee would definitely true midi someone truly petite"

# %%
reviews_df['review_clean'][10]
# Out:
# 'run small esp zipper area run order sp typically fit tight look feel cheap pull cause rip pretty disappointed go christmas year needless say go back'

# %% [markdown]
# # Split Data into train and test set

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
X = reviews_df['review_clean']
y = reviews_df['Recommended IND']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %% [markdown]
# Next, we create a numerical feature vector for each document

# %% [markdown]
# ## CountVectorizer for Pipeline (Count)

# %%
vect = CountVectorizer(min_df=5, ngram_range=(1,4)).fit(X_train)

X_train_vectorized = vect.transform(X_train)

len(vect.get_feature_names())
# Out:
# 20389

# %%
from sklearn.linear_model import SGDClassifier , LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# # SVM Model 1

# %%
model_svm = Pipeline([('vect', CountVectorizer(min_df=5, ngram_range=(1, 4))),
                    ('tfidf', TfidfTransformer()),
                    ('clf-svm',SGDClassifier(loss='hinge', random_state=42)),
                    ])

model_svm.fit(X_train, y_train)

ytest = np.array(y_test)
y_predict = model_svm.predict(X_test)

# %%
print('accuracy %s' % accuracy_score(y_predict, y_test))
print(classification_report(ytest, y_predict))
# Out:
# accuracy 0.8898211525723118
#               precision    recall  f1-score   support
#
#            0       0.82      0.54      0.65       857
#            1       0.90      0.97      0.93      3672
#
#     accuracy                           0.89      4529
#    macro avg       0.86      0.76      0.79      4529
# weighted avg       0.88      0.89      0.88      4529

# %% [markdown]
# # SVM Model 2

# %%
model_svm2 = Pipeline([('vect', CountVectorizer(min_df=5, ngram_range=(1, 4))),
                    ('tfidf', TfidfTransformer()),
                    ('clf-svm',SGDClassifier(loss='squared_hinge', random_state=42)),
                    ])

model_svm2.fit(X_train, y_train)

ytest2 = np.array(y_test)
y_predict2 = model_svm2.predict(X_test)

# %%
print('accuracy %s' % accuracy_score(y_predict2, y_test))
print(classification_report(ytest2, y_predict2))
# Out:
# accuracy 0.8553764627953191
#               precision    recall  f1-score   support
#
#            0       0.63      0.57      0.60       857
#            1       0.90      0.92      0.91      3672
#
#     accuracy                           0.86      4529
#    macro avg       0.77      0.75      0.75      4529
# weighted avg       0.85      0.86      0.85      4529

# %% [markdown]
# # Random Forest Model 1

# %%
model_rf = Pipeline([('vect', CountVectorizer(min_df=5, ngram_range=(1,4))),
                    ('tfidf', TfidfTransformer()),
                    ('clf-rf', RandomForestClassifier(n_estimators=50, criterion = 'entropy')),
                    ])

model_rf.fit(X_train, y_train)

ytest = np.array(y_test)
pred = model_rf.predict(X_test)

# %%
print('accuracy %s' % accuracy_score(pred, y_test))
print(classification_report(ytest, pred))
# Out:
# accuracy 0.8496356811658202
#               precision    recall  f1-score   support
#
#            0       0.83      0.26      0.39       857
#            1       0.85      0.99      0.91      3672
#
#     accuracy                           0.85      4529
#    macro avg       0.84      0.62      0.65      4529
# weighted avg       0.85      0.85      0.82      4529

# %% [markdown]
# # Random Forest Model 2

# %%
model_rf2 = Pipeline([('vect', CountVectorizer(min_df=5, ngram_range=(1,4))),
                    ('tfidf', TfidfTransformer()),
                    ('clf-rf', RandomForestClassifier()),
                    ])

model_rf2.fit(X_train, y_train)

ytest2 = np.array(y_test)
pred2 = model_rf2.predict(X_test)

# %%
print('accuracy %s' % accuracy_score(pred2, y_test))
print(classification_report(ytest2, pred2))
# Out:
# accuracy 0.8595716493707221
#               precision    recall  f1-score   support
#
#            0       0.87      0.30      0.45       857
#            1       0.86      0.99      0.92      3672
#
#     accuracy                           0.86      4529
#    macro avg       0.86      0.65      0.68      4529
# weighted avg       0.86      0.86      0.83      4529

# %% [markdown]
# # Score Comparison Between Model

# %%
svm_acc = accuracy_score(y_predict, y_test)
rf_acc = accuracy_score(pred, y_test)
svm_acc2 = accuracy_score(y_predict2, y_test)
rf_acc2 = accuracy_score(pred2, y_test)

models = pd.DataFrame({
                      'Model': ['Support Vector Machines 1', 'Random Forest 1','Support Vector Machines 2', 'Random Forest 2'],
                      'Score': [svm_acc, rf_acc,svm_acc2, rf_acc2]})
models.sort_values(by='Score', ascending=False)
# Out:
#                        Model     Score
# 0  Support Vector Machines 1  0.889821
# 3            Random Forest 2  0.859572
# 2  Support Vector Machines 2  0.855376
# 1            Random Forest 1  0.849636
